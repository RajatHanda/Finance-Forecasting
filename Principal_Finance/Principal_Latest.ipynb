# %%
from sklearn.feature_selection import SelectPercentile
import pandas as pd
from sklearn.feature_selection import f_regression
import numpy as np
import pandas as pd
from sklearn import linear_model as lm
from sklearn import metrics
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import Ridge
import scipy.stats as stat
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X_train = pd.read_csv('Pr_train_20.csv',parse_dates=['PERIOD (FORMATTED)'],
                 infer_datetime_format=True, encoding='utf-8')

# %%
y_train=X_train['Excess']
X_train.drop(['Excess', 'ACCX','CASH_P.1','IDENTIFIER','PERIOD (FORMATTED)','FUTURE 24 WEEK RETURNS','RANK','RVM_CFO_AST.1','TECHNICAL1.1'], axis=1,inplace =True)

# %%
X_train.columns
# Out:
# Index(['1M_RET', 'MCAP', '1SS_ERNQLT', 'IST_SURPY1', 'ARM_PFD_COMP',
#        'RET24M_L1M', 'RSI_12M.1', 'MIN12M.1', 'EV.1', 'VALUE_COM.1',
#        'QUALITY.1', 'RISK', 'PP_RANK'],
#       dtype='object')

# %%
Selector_f = SelectPercentile(f_regression, percentile=25)
Selector_f.fit(X_train,y_train)
# Out:
# SelectPercentile(percentile=25,
#          score_func=<function f_regression at 0x1088c4268>)

# %%
d={}
for n,s in zip(X_train.columns,Selector_f.scores_):
    d[s]=n
    print ("F-score: %3.2ft for feature %s " % (s,n))
# Out:
# F-score: 584.78t for feature 1M_RET
# F-score: 98.10t for feature MCAP
# F-score: 3070.21t for feature 1SS_ERNQLT
# F-score: 422.15t for feature IST_SURPY1
# F-score: 4307.78t for feature ARM_PFD_COMP
# F-score: 4753.28t for feature RET24M_L1M
# F-score: 1893.97t for feature RSI_12M.1
# F-score: 1765.77t for feature MIN12M.1
# F-score: 249.88t for feature EV.1
# F-score: 1039.91t for feature VALUE_COM.1
# F-score: 1455.59t for feature QUALITY.1
# F-score: 2543.64t for feature RISK
# F-score: 2317.29t for feature PP_RANK

# %%
sorted(d.items())
# Out:
# [(98.095433847459248, 'MCAP'),
#  (249.88039988187461, 'EV.1'),
#  (422.1454977420193, 'IST_SURPY1'),
#  (584.77949401335741, '1M_RET'),
#  (1039.9131637438966, 'VALUE_COM.1'),
#  (1455.5941331949757, 'QUALITY.1'),
#  (1765.7711790720737, 'MIN12M.1'),
#  (1893.9650441576468, 'RSI_12M.1'),
#  (2317.2895598220557, 'PP_RANK'),
#  (2543.6443596401386, 'RISK'),
#  (3070.2111091678471, '1SS_ERNQLT'),
#  (4307.7833306192233, 'ARM_PFD_COMP'),
#  (4753.2770666422939, 'RET24M_L1M')]

# %%
from sklearn import model_selection
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()
model.fit(X_train, y_train)
print(model.feature_importances_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-60f401e5fac1> in <module>()
#       1 model = ExtraTreesClassifier()
# ----> 2 model.fit(X_train, y_train)
#       3 print(model.feature_importances_)
#
# /usr/local/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     271         self.n_outputs_ = y.shape[1]
#     272
# --> 273         y, expanded_class_weight = self._validate_y_class_weight(y)
#     274
#     275         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# /usr/local/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _validate_y_class_weight(self, y)
#     469
#     470     def _validate_y_class_weight(self, y):
# --> 471         check_classification_targets(y)
#     472
#     473         y = np.copy(y)
#
# /usr/local/lib/python3.6/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171                       'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'continuous'

# %%
'RISK''1SS_ERNQLT' 'ARM_PFD_COMP''RET24M_L1M'
'QUALITY.1' 'MIN12M.1' 'RSI_12M.1' 'PP_RANK'

# %%
 P_train = X_train[['RISK','1SS_ERNQLT','ARM_PFD_COMP','RET24M_L1M','QUALITY.1', 'MIN12M.1', 'RSI_12M.1', 'PP_RANK']]

# %%
P_train.head()
# Out:
#        RISK  1SS_ERNQLT  ARM_PFD_COMP  RET24M_L1M  QUALITY.1  MIN12M.1  \
# 0  0.014736    0.001082     -0.288839   -0.002757  -0.019840 -0.004266
# 1  0.005954    0.018936     -0.036314    0.000010  -0.001720  0.000592
# 2  0.059482    0.130047      0.236413    0.004571   0.001062  0.010132
# 3  0.011318   -0.354802      0.256615   -0.000507  -0.004681  0.005278
# 4  0.020004    0.018936      0.377827   -0.000229  -0.002440  0.011014
#
#    RSI_12M.1   PP_RANK
# 0  -0.115162 -0.244777
# 1   0.031485  0.068354
# 2   0.058348 -0.436697
# 3  -0.014272 -0.315484
# 4   0.030606 -0.396293

# %%
X_train= pd.DataFrame(X_train['Excess'])

# %%
X_train.head()
# Out:
#                        Excess
# PERIOD (FORMATTED)
# 2015-08-07         -25.108537
# 2015-08-14         -14.344045
# 2015-08-14         -16.692228
# 2015-08-14         -13.234320
# 2015-08-14          -5.039901

# %%
pv = pd.pivot_table(X_train, index=X_train.index.month, columns=X_train.index.year,
                    values='Excess', aggfunc='sum')
pv
# Out:
# PERIOD (FORMATTED)           2010           2011           2012          2013  \
# PERIOD (FORMATTED)
# 1                   -78475.983271  -10655.007799  -39970.480026 -23269.858238
# 2                    36598.366885  -89507.104475 -124366.611285  14955.827606
# 3                   -49156.250469 -186246.026907 -120312.429878 -12211.311537
# 4                        3.681596 -354859.602412  -33016.556827  56651.126428
# 5                   195025.956792 -216089.273434   44938.284723  40456.339577
# 6                   196858.317232 -240997.515454  121195.703871  92871.229466
# 7                   288560.048432 -330790.491879  146845.329704  75156.415266
# 8                   214285.530866   20330.077257  196414.981648  55268.612689
# 9                   162973.308659  176019.207812   96133.805559  36767.312194
# 10                   97581.295419   92851.682568   99182.530999  -2028.694175
# 11                   88945.039700   79842.194419  192361.635220  12031.156995
# 12                   13538.601520  -33424.253741   78246.464362  55932.562897
#
# PERIOD (FORMATTED)           2014           2015           2016
# PERIOD (FORMATTED)
# 1                   102604.069423   26092.538946  144338.935456
# 2                    63329.726406  -75632.740833  227334.248160
# 3                    66115.350826 -171491.230616            NaN
# 4                   -21936.739713 -219082.977541            NaN
# 5                   -65894.265856 -243515.261839            NaN
# 6                   -71788.084398 -190164.512928            NaN
# 7                   -93221.389352 -262896.390823            NaN
# 8                   -94145.104036 -214776.206204            NaN
# 9                   -50239.543322  -80474.504274            NaN
# 10                   75714.402541  -73562.610060            NaN
# 11                   61227.773894  -34005.315569            NaN
# 12                   59394.273427    3230.381733            NaN

# %%
# %matplotlib inline
pv.plot()

# %%
# Getting only best values from Year when market is rising
year=[2011,2014,2015,2016]
X_train[X_train.year != year]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-b26013e62d33> in <module>()
#       1 year=[2011,2014,2015,2016]
# ----> 2 X_train[X_train.year != year]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'year'

# %%
df_Rising = X_train[(X_train['PERIOD (FORMATTED)'].dt.year ==2010) | (X_train['PERIOD (FORMATTED)'].dt.year ==2012) |(X_train['PERIOD (FORMATTED)'].dt.year ==2013)]

# %%
import datetime as dt
max(df_Rising['PERIOD (FORMATTED)'].dt.year)
# Out:
# 2013

# %%
df_Rising.head()
# Out:
#     IDENTIFIER PERIOD (FORMATTED)      RANK    1M_RET      MCAP  1SS_ERNQLT  \
# 357     244097         2013-07-19 -0.396952 -0.000929 -0.002078    0.311865
# 358     619560         2013-07-19 -0.114123  0.000178 -0.000580   -0.435610
# 359     220015         2013-07-26 -0.437356  0.000150 -0.001867   -0.001266
# 360   41987010         2013-08-02  0.259614  0.000764 -0.002002   -0.183085
# 361   30040W10         2013-08-02  0.148503  0.000868 -0.000103   -0.435610
#
#      IST_SURPY1      ACCX  ARM_PFD_COMP  RET24M_L1M    ...      CASH_P.1  \
# 357   -0.005627  0.247988      0.448534   -0.003373    ...      0.001942
# 358   -0.000806  0.053920     -0.127223   -0.001795    ...     -0.001031
# 359    0.001448  0.010291      0.206110   -0.003808    ...      0.000878
# 360    0.000105 -0.067892     -0.096920   -0.000906    ...     -0.001204
# 361    0.000222  0.003119      0.064696   -0.000416    ...     -0.002541
#
#          EV.1  RVM_CFO_AST.1  VALUE_COM.1  QUALITY.1      RISK  TECHNICAL1.1  \
# 357 -0.002096       0.042859    -0.024160   0.184801  0.040879     -0.069352
# 358  0.002389      -0.061093    -0.025668  -0.014465  0.098685      0.165288
# 359 -0.001901       0.012094     0.026129  -0.031957 -0.065077     -0.060646
# 360 -0.001920       0.024269     0.045897   0.045009 -0.019655     -0.086711
# 361  0.000119      -0.030202    -0.006329   0.051355  0.021340     -0.017530
#
#       PP_RANK  FUTURE 24 WEEK RETURNS     Excess
# 357  0.118859              -16.806835 -20.077810
# 358  0.391586              -12.011481 -15.282457
# 359  0.169364                4.742842   1.471867
# 360 -0.153868                0.148528  -3.122447
# 361 -0.032656               -3.057422  -6.328397
#
# [5 rows x 22 columns]

# %%
df_Decreasing = X_train[(X_train['PERIOD (FORMATTED)'].dt.year ==2011) | (X_train['PERIOD (FORMATTED)'].dt.year ==2014) |(X_train['PERIOD (FORMATTED)'].dt.year ==2015)]

# %%
min(df_Decreasing['PERIOD (FORMATTED)'].dt.year)
# Out:
# 2011

# %%
df_train=X_train[cols]

# %%
y=X_train['Excess']

# %%
from sklearn.ensemble import ExtraTreesRegressor
import numpy as np
from sklearn import metrics

# %%
ETR_model = ExtraTreesRegressor(n_estimators=100, max_depth=4, n_jobs=-1, random_state=17, verbose=0)
model2 = ETR_model.fit(X_train[cols], X_train['Excess'])

# %%
df_test=pd.read_csv('Pr_test_20.csv',parse_dates=['PERIOD (FORMATTED)'],
                 infer_datetime_format=True, encoding='utf-8')

# %%
Preds_Excess_2=model2.predict(df_test[cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_2))
# Out:
# 18.948325137784831

# %%
ETR_model = ExtraTreesRegressor(n_estimators=100, max_depth=4, n_jobs=-1, random_state=17, verbose=0)
model2 = ETR_model.fit(df_Rising[cols],df_Rising['Excess'])

# %%
Preds_Excess_2=model2.predict(df_test[cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_2))
# Out:
# 19.450460786072259

# %%
ETR_model = ExtraTreesRegressor(n_estimators=100, max_depth=4, n_jobs=-1, random_state=17, verbose=0)
model2 = ETR_model.fit(df_Decreasing[cols],df_Decreasing['Excess'])

# %%
Preds_Excess_2=model2.predict(df_test[cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_2))
# Out:
# 19.569808689819126

# %%
cols_keep=['PERIOD (FORMATTED)','IDENTIFIER','RET24M_L1M','ARM_PFD_COMP','1SS_ERNQLT','PP_RANK','RISK','Excess']
cols=['RET24M_L1M','ARM_PFD_COMP','1SS_ERNQLT','PP_RANK','RISK']

# %%
#X_train.groupby('IDENTIFIER')['RANK'].apply(pd.rolling_mean, 2, min_periods=1)
X_train=X_train[cols_keep]
X_train.head()
# Out:
#   PERIOD (FORMATTED) IDENTIFIER  RET24M_L1M  ARM_PFD_COMP  1SS_ERNQLT  \
# 0         2015-08-07     B66Y3W   -0.002757     -0.288839    0.001082
# 1         2015-08-14   46625H10    0.000010     -0.036314    0.018936
# 2         2015-08-14   22531010    0.004571      0.236413    0.130047
# 3         2015-08-14   68193610   -0.000507      0.256615   -0.354802
# 4         2015-08-14   05348410   -0.000229      0.377827    0.018936
#
#     PP_RANK      RISK     Excess
# 0 -0.244777  0.014736 -25.108537
# 1  0.068354  0.005954 -14.344045
# 2 -0.436697  0.059482 -16.692228
# 3 -0.315484  0.011318 -13.234320
# 4 -0.396293  0.020004  -5.039901

# %%
for val in cols:
    X_train[val+'_Rol'] = X_train.groupby('IDENTIFIER')[val].rolling(24).mean().reset_index(0,drop=True)

# %%
X_train.head()
# Out:
#   PERIOD (FORMATTED) IDENTIFIER  RET24M_L1M  ARM_PFD_COMP  1SS_ERNQLT  \
# 0         2015-08-07     B66Y3W   -0.002757     -0.288839    0.001082
# 1         2015-08-14   46625H10    0.000010     -0.036314    0.018936
# 2         2015-08-14   22531010    0.004571      0.236413    0.130047
# 3         2015-08-14   68193610   -0.000507      0.256615   -0.354802
# 4         2015-08-14   05348410   -0.000229      0.377827    0.018936
#
#     PP_RANK      RISK     Excess  RET24M_L1M_Rol  ARM_PFD_COMP_Rol  \
# 0 -0.244777  0.014736 -25.108537             NaN               NaN
# 1  0.068354  0.005954 -14.344045             NaN               NaN
# 2 -0.436697  0.059482 -16.692228             NaN               NaN
# 3 -0.315484  0.011318 -13.234320             NaN               NaN
# 4 -0.396293  0.020004  -5.039901             NaN               NaN
#
#    1SS_ERNQLT_Rol  PP_RANK_Rol  RISK_Rol
# 0             NaN          NaN       NaN
# 1             NaN          NaN       NaN
# 2             NaN          NaN       NaN
# 3             NaN          NaN       NaN
# 4             NaN          NaN       NaN

# %%
df_test=df_test[cols_keep]
for val in cols:
    df_test[val+'_Rol'] = df_test.groupby('IDENTIFIER')[val].rolling(24).mean().reset_index(0,drop=True)

df_test.head()
# Out:
#   PERIOD (FORMATTED) IDENTIFIER  RET24M_L1M  ARM_PFD_COMP  1SS_ERNQLT  \
# 0         2016-09-02     040828   -0.004151      0.347524   -0.334600
# 1         2016-09-02   75935160   -0.000223      0.165706   -0.223489
# 2         2016-09-02     604978   -0.000638      0.357625   -0.304297
# 3         2016-09-02     607572   -0.002547      0.024292   -0.041670
# 4         2016-09-02     615667   -0.002400      0.004289    0.109845
#
#     PP_RANK      RISK     Excess  RET24M_L1M_Rol  ARM_PFD_COMP_Rol  \
# 0  0.482495  0.116931  -1.194258             NaN               NaN
# 1  0.068354 -0.031525   9.699813             NaN               NaN
# 2  0.351182  0.055283 -19.711595             NaN               NaN
# 3 -0.042757  0.045635   6.848615             NaN               NaN
# 4  0.001638 -0.029005  18.721764             NaN               NaN
#
#    1SS_ERNQLT_Rol  PP_RANK_Rol  RISK_Rol
# 0             NaN          NaN       NaN
# 1             NaN          NaN       NaN
# 2             NaN          NaN       NaN
# 3             NaN          NaN       NaN
# 4             NaN          NaN       NaN

# %%
X_train.isnull().values.any()
X_train.isnull().sum()
# Out:
# PERIOD (FORMATTED)         0
# IDENTIFIER                 0
# RET24M_L1M                 0
# ARM_PFD_COMP               0
# 1SS_ERNQLT                 0
# PP_RANK                    0
# RISK                       0
# Excess                     0
# RET24M_L1M_Rol        107467
# ARM_PFD_COMP_Rol      107467
# 1SS_ERNQLT_Rol        107467
# PP_RANK_Rol           107467
# RISK_Rol              107467
# dtype: int64

# %%
df_test.isnull().values.any()
df_test.isnull().sum()
# Out:
# PERIOD (FORMATTED)        0
# IDENTIFIER                0
# RET24M_L1M                0
# ARM_PFD_COMP              0
# 1SS_ERNQLT                0
# PP_RANK                   0
# RISK                      0
# Excess                    0
# RET24M_L1M_Rol        82373
# ARM_PFD_COMP_Rol      82373
# 1SS_ERNQLT_Rol        82373
# PP_RANK_Rol           82373
# RISK_Rol              82373
# dtype: int64

# %%
X_train=X_train.dropna(subset=['RET24M_L1M_Rol','ARM_PFD_COMP_Rol','1SS_ERNQLT_Rol','PP_RANK_Rol','RISK_Rol' ])
X_train.isnull().values.any()
X_train.isnull().sum()
# Out:
# PERIOD (FORMATTED)    0
# IDENTIFIER            0
# RET24M_L1M            0
# ARM_PFD_COMP          0
# 1SS_ERNQLT            0
# PP_RANK               0
# RISK                  0
# Excess                0
# RET24M_L1M_Rol        0
# ARM_PFD_COMP_Rol      0
# 1SS_ERNQLT_Rol        0
# PP_RANK_Rol           0
# RISK_Rol              0
# dtype: int64

# %%
df_test=df_test.dropna(subset=['RET24M_L1M_Rol','ARM_PFD_COMP_Rol','1SS_ERNQLT_Rol','PP_RANK_Rol','RISK_Rol' ])
df_test.isnull().values.any()
df_test.isnull().sum()
# Out:
# PERIOD (FORMATTED)    0
# IDENTIFIER            0
# RET24M_L1M            0
# ARM_PFD_COMP          0
# 1SS_ERNQLT            0
# PP_RANK               0
# RISK                  0
# Excess                0
# RET24M_L1M_Rol        0
# ARM_PFD_COMP_Rol      0
# 1SS_ERNQLT_Rol        0
# PP_RANK_Rol           0
# RISK_Rol              0
# dtype: int64

# %% [markdown]
# ## Extra Tree

# %%
new_cols=['RET24M_L1M','ARM_PFD_COMP','1SS_ERNQLT','PP_RANK','RISK','RET24M_L1M_Rol','ARM_PFD_COMP_Rol','1SS_ERNQLT_Rol','PP_RANK_Rol','RISK_Rol']
ETR_model = ExtraTreesRegressor(n_estimators=100, max_depth=4, n_jobs=-1, random_state=17, verbose=0)
model2 = ETR_model.fit(X_train[new_cols],X_train['Excess'])

# %%
Preds_Excess_2=model2.predict(df_test[new_cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_2))
# Out:
# 18.955847804472413

# %%
#MAE
metrics.mean_absolute_error(df_test['Excess'],Preds_Excess_2)
# Out:
# 13.63528215230043

# %%
imp = pd.DataFrame(index=new_cols)
imp['train'] = pd.Series(model2.feature_importances_, index=new_cols)
ax = imp.sort_values('train').tail(10).plot.barh(title='Feature importances With Normal Metrics(ETR)', figsize=(10,6))

# %% [markdown]
# ## Linear Model

# %%
lm_model=lm.LinearRegression()
lm_model.fit(X_train[new_cols], X_train['Excess'])
# Out:
# /usr/local/lib/python3.6/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Preds_Excess=lm_model.predict(df_test[new_cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess))
# Out:
# 19.06911870624187

# %% [markdown]
# ## Ridge

# %%
Rid=Ridge()
model3=Rid.fit(X_train[new_cols], X_train['Excess'])

# %%
Preds_Excess_4=model3.predict(df_test[new_cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_4))
# Out:
# 19.073033300521676

# %% [markdown]
# ## Without Lag ET

# %% [markdown]
# ### ET

# %%
ETR_model = ExtraTreesRegressor(n_estimators=100, max_depth=5, n_jobs=-1, random_state=17, verbose=0)
model2 = ETR_model.fit(X_train[cols],X_train['Excess'])

# %%
Preds_Excess_2=model2.predict(df_test[cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_2))
# Out:
# 18.916727641651939

# %% [markdown]
# ### Ridge

# %%
Rid=Ridge()
model3=Rid.fit(X_train[cols], X_train['Excess'])

# %%
Preds_Excess_4=model3.predict(df_test[cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_4))
# Out:
# 18.937075504335581

# %%
Preds_Excess_3=(model2.predict(df_test[cols])*0.95)+(model3.predict(df_test[cols])*0.05)
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_3))
# Out:
# 18.916026357938577

# %%
cols
# Out:
# ['RET24M_L1M', 'ARM_PFD_COMP', '1SS_ERNQLT', 'PP_RANK', 'RISK']

# %%
X_train=X_train.set_index('PERIOD (FORMATTED)')
pv = pd.pivot_table(X_train, index=X_train.index.month, columns=X_train.index.year,
                    values='ARM_PFD_COMP', aggfunc='sum')
pv
pv.plot()

# %%
pv = pd.pivot_table(X_train, index=X_train.index.month, columns=X_train.index.year,
                    values='RET24M_L1M', aggfunc='sum')
pv
pv.plot()

# %%
pv = pd.pivot_table(X_train, index=X_train.index.month, columns=X_train.index.year,
                    values='1SS_ERNQLT', aggfunc='sum')
pv
pv.plot()

# %%
pv = pd.pivot_table(X_train, index=X_train.index.month, columns=X_train.index.year,
                    values='PP_RANK', aggfunc='sum')
pv
pv.plot()

# %%
pv = pd.pivot_table(X_train, index=X_train.index.month, columns=X_train.index.year,
                    values='RISK', aggfunc='sum')
pv
pv.plot()

# %%
X_train.head()
# Out:
#                    IDENTIFIER  RET24M_L1M  ARM_PFD_COMP  1SS_ERNQLT   PP_RANK  \
# PERIOD (FORMATTED)
# 2013-05-31             268236   -0.003591      0.024292    0.001082  0.351182
# 2014-08-29           05561Q20   -0.000534      0.367726    0.301764 -0.032656
# 2016-02-05           55261F10   -0.001135     -0.107021    0.008835 -0.062959
# 2015-10-23             BYXS69   -0.000159     -0.096920    0.001082  0.482495
# 2015-10-30             BYXS69   -0.000571     -0.268637    0.001082  0.492596
#
#                         RISK     Excess  RET24M_L1M_Rol  ARM_PFD_COMP_Rol  \
# PERIOD (FORMATTED)
# 2013-05-31         -0.084997  -8.056525       -0.002637         -0.069910
# 2014-08-29         -0.050128 -14.086170       -0.000002          0.104679
# 2016-02-05         -0.008794   4.231888        0.000140          0.057541
# 2015-10-23         -0.000026 -14.095878       -0.000827         -0.096499
# 2015-10-30         -0.000026  -8.189619       -0.000805         -0.110809
#
#                     1SS_ERNQLT_Rol  PP_RANK_Rol  RISK_Rol
# PERIOD (FORMATTED)
# 2013-05-31               -0.120815     0.208505 -0.060759
# 2014-08-29                0.115737    -0.158498 -0.079517
# 2016-02-05                0.084592    -0.052858 -0.029239
# 2015-10-23               -0.074822     0.145374 -0.010236
# 2015-10-30               -0.071778     0.170206 -0.008719

# %%
import seaborn as sns
corrmat = X_train.corr(method='spearman')
f, ax = plt.subplots(figsize=(11, 11))
sns.heatmap(corrmat, cbar=False, annot=True, square=True, fmt='.0f', 
            annot_kws={'size': 8})
plt.title('High-corrlation Features')
plt.show()

# %%
df_Rising = X_train[(X_train['PERIOD (FORMATTED)'].dt.year ==2011) | (X_train['PERIOD (FORMATTED)'].dt.year ==2012) |(X_train['PERIOD (FORMATTED)'].dt.year ==2013)]

# %%
X_train.columns
# Out:
# Index(['PERIOD (FORMATTED)', 'IDENTIFIER', 'RET24M_L1M', 'ARM_PFD_COMP',
#        '1SS_ERNQLT', 'PP_RANK', 'RISK', 'Excess', 'RET24M_L1M_Rol',
#        'ARM_PFD_COMP_Rol', '1SS_ERNQLT_Rol', 'PP_RANK_Rol', 'RISK_Rol'],
#       dtype='object')

# %%
ETR_model = ExtraTreesRegressor(n_estimators=100, max_depth=5, n_jobs=-1, random_state=17, verbose=0)
model2 = ETR_model.fit(X_train[cols],X_train['Excess'])

# %%
Preds_Excess_2=model2.predict(df_test[cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_2))
# Out:
# 18.912737148408176

# %%
df_test['Excess_Predicted_ET_Lag']=Preds_Excess_2

# %%
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
print ("Current size:", fig_size)
fig_size[0] = 12
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size
print ("Current size:", fig_size)
# Out:
# Current size: [6.0, 4.0]
# Current size: [12, 10]

# %%
# Non-Lag Features
df_test.set_index('PERIOD (FORMATTED)')
df_test[['Excess','Excess_Predicted_ET']].iloc[:100,:].plot(marker='.')

# %%
df_test[['Excess','Excess_Predicted_ET_Lag']].iloc[:100,:].plot(marker='.')

# %%
X_train.hist(column='Excess')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10dbfc6d8>]], dtype=object)

# %%
min(X_train['Excess'])
# Out:
# -102.84259216930641

# %%
temp=X_train[X_train.Excess <= 20]

# %%
temp=temp[temp.Excess >= -20]

# %%
len(temp['Excess'])
# Out:
# 692483

# %%
ETR_model = ExtraTreesRegressor(n_estimators=100, max_depth=4, n_jobs=-1, random_state=17, verbose=0)
model2 = ETR_model.fit(temp[new_cols],temp['Excess'])

# %%
Preds_Excess_2=model2.predict(df_test[new_cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_2))
# Out:
# 18.861968926059834

# %%
df_test['Excess_Predicted_ET_Lag_Clipped']=Preds_Excess_2

# %%
df_test[['Excess','Excess_Predicted_ET_Lag_Clipped']].iloc[:100,:].plot(marker='.')

# %%
#Lag
rol=['RET24M_L1M','ARM_PFD_COMP','1SS_ERNQLT','PP_RANK','RISK']

# %%
for rol in rol:
    df_test[rol+'_LagDiff']=df_test[rol]-df_test[rol+"_Rol"]

# %%
for rol in rol:
    X_train[rol+'_LagDiff']=X_train[rol]-X_train[rol+"_Rol"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2521             try:
# -> 2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'R'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-368-49ea5795cae7> in <module>()
#       1 for rol in rol:
# ----> 2     X_train[rol+'_LagDiff']=X_train[rol]-X_train[rol+"_Rol"]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3836
#    3837             if not isna(item):
# -> 3838                 loc = self.items.get_loc(item)
#    3839             else:
#    3840                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
# -> 2524                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2525
#    2526         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'R'

# %%
X_train.head()
# Out:
#   PERIOD (FORMATTED) IDENTIFIER  RET24M_L1M  ARM_PFD_COMP  1SS_ERNQLT  \
# 0         2013-05-31     268236   -0.003591      0.024292    0.001082
# 1         2014-08-29   05561Q20   -0.000534      0.367726    0.301764
# 2         2016-02-05   55261F10   -0.001135     -0.107021    0.008835
# 3         2015-10-23     BYXS69   -0.000159     -0.096920    0.001082
# 4         2015-10-30     BYXS69   -0.000571     -0.268637    0.001082
#
#     PP_RANK      RISK     Excess  RET24M_L1M_Rol  ARM_PFD_COMP_Rol    ...     \
# 0  0.351182 -0.084997  -8.056525       -0.002637         -0.069910    ...
# 1 -0.032656 -0.050128 -14.086170       -0.000002          0.104679    ...
# 2 -0.062959 -0.008794   4.231888        0.000140          0.057541    ...
# 3  0.482495 -0.000026 -14.095878       -0.000827         -0.096499    ...
# 4  0.492596 -0.000026  -8.189619       -0.000805         -0.110809    ...
#
#    RET24M_L1MLagDiff  ARM_PFD_COMPLagDiff  1SS_ERNQLTLagDiff  PP_RANKLagDiff  \
# 0          -0.000955             0.094202           0.121897        0.142677
# 1          -0.000532             0.263047           0.186027        0.125842
# 2          -0.001275            -0.164562          -0.075758       -0.010101
# 3           0.000668            -0.000421           0.075904        0.337121
# 4           0.000234            -0.157828           0.072860        0.322391
#
#    RISKLagDiff  RET24M_L1M_SUM  ARM_PFD_COMP_SUM  1SS_ERNQLT_SUM  PP_RANK_SUM  \
# 0    -0.024238       -0.006228         -0.045618       -0.119733     0.559688
# 1     0.029389       -0.000535          0.472405        0.417501    -0.191154
# 2     0.020445       -0.000995         -0.049480        0.093427    -0.115817
# 3     0.010210       -0.000986         -0.193419       -0.073740     0.627869
# 4     0.008693       -0.001376         -0.379446       -0.070696     0.662802
#
#    RISK_SUM
# 0 -0.145757
# 1 -0.129645
# 2 -0.038033
# 3 -0.010262
# 4 -0.008745
#
# [5 rows x 23 columns]

# %%
df_test.head()
# Out:
#       PERIOD (FORMATTED) IDENTIFIER  RET24M_L1M  ARM_PFD_COMP  1SS_ERNQLT  \
# 57198         2016-09-16   94262220    0.001478     -0.026213    0.392673
# 59655         2016-12-09     688507    0.001029     -0.046415    0.261360
# 59676         2017-02-10     688507    0.001696      0.175807    0.261360
# 61735         2016-12-23   94262220    0.000956     -0.107021    0.342168
# 62075         2016-11-11   90384S30    0.003631      0.276817    0.220956
#
#         PP_RANK      RISK     Excess  RET24M_L1M_Rol  ARM_PFD_COMP_Rol  \
# 57198 -0.396293 -0.054733  -3.185994        0.001213         -0.035472
# 59655 -0.335687 -0.021561   6.519625        0.001616          0.007457
# 59676 -0.093262 -0.020787  -1.013153        0.001653          0.009982
# 61735 -0.406394 -0.043878 -11.603564        0.001185         -0.037577
# 62075 -0.456899 -0.022081   7.476496        0.004240          0.258720
#
#            ...       PP_RANK_Rol  RISK_Rol  Excess_Predicted_ET  \
# 57198      ...         -0.408919 -0.059510             2.434844
# 59655      ...         -0.326006 -0.022514             1.883203
# 59676      ...         -0.316747 -0.022566             1.460053
# 61735      ...         -0.409340 -0.058943             2.150025
# 62075      ...         -0.469525 -0.046741             1.494262
#
#        Excess_Predicted_ET_Lag  Excess_Predicted_ET_Lag_Clipped  \
# 57198                 1.377404                         0.904947
# 59655                 2.197352                         0.730837
# 59676                 2.367790                         0.716519
# 61735                 1.121480                         0.869899
# 62075                 5.052638                         1.293216
#
#        RET24M_L1M_LagDiff  ARM_PFD_COMP_LagDiff  1SS_ERNQLT_LagDiff  \
# 57198            0.000265              0.009259            0.030303
# 59655           -0.000588             -0.053872           -0.021044
# 59676            0.000043              0.165825           -0.021044
# 61735           -0.000229             -0.069444           -0.017677
# 62075           -0.000609              0.018098           -0.036195
#
#        PP_RANK_LagDiff  RISK_LagDiff
# 57198         0.012626      0.004777
# 59655        -0.009680      0.000953
# 59676         0.223485      0.001779
# 61735         0.002946      0.015065
# 62075         0.012626      0.024660
#
# [5 rows x 21 columns]

# %%
for rol in rol:
    X_train[rol+'_SUM']=X_train[rol]+X_train[rol+"_Rol"]

# %%
for rol in rol:
    df_test[rol+'_SUM']=df_test[rol]+df_test[rol+"_Rol"]

# %%
t_cols = [x for x in X_train.columns.values if x not in ['PERIOD (FORMATTED)',
 'IDENTIFIER','Excess']]

# %%
t_cols
# Out:
# ['RET24M_L1M',
#  'ARM_PFD_COMP',
#  '1SS_ERNQLT',
#  'PP_RANK',
#  'RISK',
#  'RET24M_L1M_Rol',
#  'ARM_PFD_COMP_Rol',
#  '1SS_ERNQLT_Rol',
#  'PP_RANK_Rol',
#  'RISK_Rol',
#  'RET24M_L1MLagDiff',
#  'ARM_PFD_COMPLagDiff',
#  '1SS_ERNQLTLagDiff',
#  'PP_RANKLagDiff',
#  'RISKLagDiff',
#  'RET24M_L1M_SUM',
#  'ARM_PFD_COMP_SUM',
#  '1SS_ERNQLT_SUM',
#  'PP_RANK_SUM',
#  'RISK_SUM']

# %%
ETR_model = ExtraTreesRegressor(n_estimators=100, max_depth=4, n_jobs=-1, random_state=17, verbose=0)
model2 = ETR_model.fit(X_train[t_cols],X_train['Excess'])

# %%
t_cols = [x for x in df_test.columns.values if x not in ['Excess_Predicted_ET',
 'Excess_Predicted_ET_Lag',
 'Excess_Predicted_ET_Lag_Clipped','PERIOD (FORMATTED)','IDENTIFIER','Excess']]

# %%
t_cols
# Out:
# ['RET24M_L1M',
#  'ARM_PFD_COMP',
#  '1SS_ERNQLT',
#  'PP_RANK',
#  'RISK',
#  'RET24M_L1M_Rol',
#  'ARM_PFD_COMP_Rol',
#  '1SS_ERNQLT_Rol',
#  'PP_RANK_Rol',
#  'RISK_Rol',
#  'RET24M_L1M_LagDiff',
#  'ARM_PFD_COMP_LagDiff',
#  '1SS_ERNQLT_LagDiff',
#  'PP_RANK_LagDiff',
#  'RISK_LagDiff',
#  'RET24M_L1M_SUM',
#  'ARM_PFD_COMP_SUM',
#  '1SS_ERNQLT_SUM',
#  'PP_RANK_SUM',
#  'RISK_SUM']

# %%
Preds_Excess_2=model2.predict(df_test[t_cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_2))
# Out:
# 18.974492973403702

# %%
df_test['Excess_Predicted_ET_Lag_1']=Preds_Excess_2

# %%
df_test[['Excess','Excess_Predicted_ET_Lag_1']].iloc[:100,:].plot(marker='.')

# %%
max(df_test['Excess'])
# Out:
# 245.31774193652492

# %%
temp=df_test[df_test.Excess <= 40]
temp=temp[temp.Excess >= -40]

# %%
Preds_Excess_2=model2.predict(df_test[t_cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_2))
# Out:
# 18.974492973403702

# %% [markdown]
# ## Changing TimeStamp

# %%
X_t=X_train.loc[(X_train['PERIOD (FORMATTED)'].dt.year >= 2011) & (X_train['PERIOD (FORMATTED)'].dt.year < 2013)]

# %%
X_test=X_train.loc[(X_train['PERIOD (FORMATTED)'].dt.month >= 6) & (X_train['PERIOD (FORMATTED)'].dt.year == 2014)]

# %%
X_t.head()
# Out:
#    PERIOD (FORMATTED) IDENTIFIER  RET24M_L1M  ARM_PFD_COMP  1SS_ERNQLT  \
# 7          2012-11-02     B0CRCP    0.000583     -0.086819    0.210855
# 11         2012-08-10     618666    0.007268     -0.399950    0.362370
# 23         2012-08-03     660990    0.000739      0.004289    0.001082
# 25         2011-08-26     B0CRCP    0.000939     -0.016112   -0.132580
# 37         2012-01-06   G5480U12    0.002545      0.004289    0.001082
#
#      PP_RANK      RISK     Excess  RET24M_L1M_Rol  ARM_PFD_COMP_Rol    ...     \
# 7  -0.325585 -0.013741  14.922325       -0.000253          0.009140    ...
# 11 -0.456899  0.040446 -12.455326        0.001626          0.089949    ...
# 23  0.320879  0.041109  45.387430        0.001946          0.009306    ...
# 25  0.048152 -0.044443  13.372319       -0.000193          0.017558    ...
# 37  0.001638  0.060106  11.158728        0.003241          0.003818    ...
#
#     RET24M_L1MLagDiff  ARM_PFD_COMPLagDiff  1SS_ERNQLTLagDiff  PP_RANKLagDiff  \
# 7            0.000836            -0.095960       2.651515e-02       -0.227273
# 11           0.005642            -0.489899       2.617845e-01       -0.192761
# 23          -0.001208            -0.005017      -4.336809e-19        0.137626
# 25           0.001132            -0.033670      -3.211279e-01        0.143098
# 37          -0.000695             0.000471      -4.336809e-19        0.000000
#
#     RISKLagDiff  RET24M_L1M_SUM  ARM_PFD_COMP_SUM  1SS_ERNQLT_SUM  \
# 7      0.012388        0.000330         -0.077679        0.395194
# 11     0.067474        0.008895         -0.310002        0.462955
# 23     0.040165        0.002685          0.013595        0.002164
# 25    -0.014449        0.000746          0.001446        0.055969
# 37     0.001487        0.005786          0.008107        0.002164
#
#     PP_RANK_SUM  RISK_SUM
# 7     -0.423898 -0.039869
# 11    -0.721036  0.013419
# 23     0.504132  0.042052
# 25    -0.046794 -0.074438
# 37     0.003276  0.118725
#
# [5 rows x 23 columns]

# %%
t_cols = [x for x in X_t.columns.values if x not in ['Excess_Predicted_ET',
 'Excess_Predicted_ET_Lag',
 'Excess_Predicted_ET_Lag_Clipped','PERIOD (FORMATTED)','IDENTIFIER','Excess']]

# %%
ETR_model = ExtraTreesRegressor(n_estimators=100, max_depth=4, n_jobs=-1, random_state=17, verbose=0)
model2 = ETR_model.fit(X_t[t_cols],X_t['Excess'])

# %%
t_cols = [x for x in X_test.columns.values if x not in ['Excess_Predicted_ET',
 'Excess_Predicted_ET_Lag',
 'Excess_Predicted_ET_Lag_Clipped','PERIOD (FORMATTED)','IDENTIFIER','Excess']]

# %%
Preds_Excess_2=model2.predict(X_test[t_cols])
#RMSE
np.sqrt(metrics.mean_squared_error(X_test['Excess'],Preds_Excess_2))
# Out:
# 23.373024189106015

# %%
imp = pd.DataFrame(index=t_cols)
imp['train'] = pd.Series(model2.feature_importances_, index=t_cols)
ax = imp.sort_values('train').tail(10).plot.barh(title='Feature importances With Normal Metrics(ETR)', figsize=(10,6))

# %%
Rid=Ridge()
model3=Rid.fit(X_train[t_cols], X_train['Excess'])

# %%
Preds_Excess_4=model3.predict(X_test[t_cols])
#RMSE
np.sqrt(metrics.mean_squared_error(X_test['Excess'],Preds_Excess_4))
# Out:
# 23.396862856119192

# %%
id='G7665A10'
temp1 = df_test[df_test.IDENTIFIER==id]
temp1[['Excess','Excess_Predicted_ET']].iloc[:20,:].plot(marker='.')

# %%
count(df_test['IDENTIFIER'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-441-df241e48ed5f> in <module>()
# ----> 1 count(df_test['IDENTIFIER'])
#
# NameError: name 'count' is not defined

# %%
id='G7665A10'
temp1 = df_test[df_test.IDENTIFIER==id]
temp1
# Out:
#       PERIOD (FORMATTED) IDENTIFIER  RET24M_L1M  ARM_PFD_COMP  1SS_ERNQLT  \
# 63640         2016-12-09   G7665A10   -0.003468     -0.420152    0.443178
# 87707         2017-02-03   G7665A10   -0.002247     -0.056516    0.443178
#
#         PP_RANK      RISK     Excess  RET24M_L1M_Rol  ARM_PFD_COMP_Rol  \
# 63640  0.017849 -0.006034 -50.068574       -0.003132         -0.253065
# 87707  0.027950 -0.013392 -50.348917       -0.003086         -0.239176
#
#                  ...              ARM_PFD_COMP_LagDiff  1SS_ERNQLT_LagDiff  \
# 63640            ...                         -0.167088            0.000842
# 87707            ...                          0.182660           -0.001263
#
#        PP_RANK_LagDiff  RISK_LagDiff  RET24M_L1M_SUM  ARM_PFD_COMP_SUM  \
# 63640        -0.065236     -0.003801       -0.006600         -0.673217
# 87707        -0.055135     -0.010441       -0.005333         -0.295692
#
#        1SS_ERNQLT_SUM  PP_RANK_SUM  RISK_SUM  Excess_Predicted_ET_Lag_1
# 63640        0.885514     0.100933 -0.008267                  -7.829499
# 87707        0.887619     0.111034 -0.016344                  -6.354032
#
# [2 rows x 27 columns]

# %%
max(df_test['IDENTIFIER'].value_counts())
# Out:
# 2

# %%
df_Rising = X_train[(X_train['PERIOD (FORMATTED)'].dt.year ==2013) | (X_train['PERIOD (FORMATTED)'].dt.year ==2014)]
df_r_test=X_train[(X_train['PERIOD (FORMATTED)'].dt.year ==2015) & (X_train['PERIOD (FORMATTED)'].dt.month >= 6) ]

# %%
ETR_model = ExtraTreesRegressor(n_estimators=100, max_depth=4, n_jobs=-1, random_state=17, verbose=0)
model2 = ETR_model.fit(df_Rising[t_cols],df_Rising['Excess'])

# %%
t_cols = [x for x in X_test.columns.values if x not in ['Excess_Predicted_ET',
 'Excess_Predicted_ET_Lag',
 'Excess_Predicted_ET_Lag_Clipped','PERIOD (FORMATTED)','IDENTIFIER','Excess']]
Preds_Excess_2=model2.predict(df_r_test[t_cols])
#RMSE
np.sqrt(metrics.mean_squared_error(df_r_test['Excess'],Preds_Excess_2))
# Out:
# 21.908118051094956

# %%
df_r_test['IDENTIFIER'].value_counts()
# Out:
# 566935      30
# P3107610    30
# 661964      30
# B5BHQP      30
# 12640810    30
# 26483E10    30
# 629817      30
# 26441150    30
# B03MSR      30
# 00971T10    30
# 672955      30
# 634427      30
# 693657      30
# B6SPB4      30
# 25674610    30
# 614278      30
# 661950      30
# 91168410    30
# 634007      30
# 618355      30
# 22002T10    30
# B05N80      30
# 17737610    30
# BYX3N4      30
# 637248      30
# 666010      30
# 642872      30
# 71270410    30
# 482030      30
# 02079K30    30
#             ..
# 92242T10     3
# 87823710     3
# 67574630     3
# 63861C10     3
# 14162410     3
# 04351G10     3
# B01VRK       3
# 05009510     3
# 24353710     3
# 00936310     3
# 39762410     3
# B3CXGM       2
# BLY0NY       2
# 076693       2
# 660599       2
# 67421510     2
# 419689       2
# 614608       2
# 53146510     2
# 55345K10     2
# 88732J20     2
# 49926D10     2
# 92345410     2
# 81809710     1
# 40650V10     1
# 80004C10     1
# B128R9       1
# 13765N10     1
# 669455       1
# 75508B10     1
# Name: IDENTIFIER, Length: 3612, dtype: int64

# %%
df_r_test['Lag']=Preds_Excess_2
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
id='B03MSR'

temp1 = df_r_test[df_r_test.IDENTIFIER==id]
temp1
# Out:
#                    IDENTIFIER  RET24M_L1M  ARM_PFD_COMP  1SS_ERNQLT   PP_RANK  \
# PERIOD (FORMATTED)
# 2015-09-25             B03MSR   -0.002579      0.468736   -0.183085 -0.153868
# 2015-10-30             B03MSR   -0.002434      0.448534    0.412875 -0.254878
# 2015-12-25             B03MSR   -0.001731     -0.086819    0.422976 -0.244777
# 2015-06-26             B03MSR   -0.002080      0.327322    0.261360 -0.194272
# 2015-07-03             B03MSR   -0.001294      0.327322    0.251259 -0.194272
# 2015-07-24             B03MSR   -0.000727      0.094999    0.251259 -0.194272
# 2015-06-19             B03MSR   -0.001559      0.458635    0.271461 -0.113464
# 2015-11-27             B03MSR   -0.002259      0.347524    0.412875 -0.254878
# 2015-10-16             B03MSR   -0.002713      0.448534   -0.172984 -0.143767
# 2015-07-10             B03MSR   -0.001441      0.307120    0.251259 -0.123565
# 2015-11-20             B03MSR   -0.002211      0.347524    0.422976 -0.184171
# 2015-11-13             B03MSR   -0.002313      0.357625    0.422976 -0.184171
# 2015-08-14             B03MSR   -0.001718      0.317221   -0.152782 -0.194272
# 2015-12-18             B03MSR   -0.001524      0.246514    0.412875 -0.254878
# 2015-07-31             B03MSR   -0.001490      0.246514    0.241158 -0.184171
# 2015-09-18             B03MSR   -0.002688      0.478837   -0.183085 -0.153868
# 2015-11-06            -0.445363  0.029392  6.025062
# 2015-09-04            -0.379706  0.039845  5.845310
# 2015-08-07            -0.275750  0.039382  5.336178
# 2015-12-04            -0.427686  0.019550  5.651623
# 2015-06-12            -0.393595  0.055495  6.558669
# 2015-10-09            -0.332989  0.041167  5.390880
# 2015-09-11            -0.301844  0.059071  3.242240
# 2015-10-02            -0.327097  0.050966  5.229641
# 2015-06-05            -0.366659  0.047300  5.820531
# 2015-08-21            -0.349403  0.042698  5.846472
# 2015-07-17            -0.247131  0.048706  4.675917
# 2015-08-28            -0.336356  0.030124  5.208210
#
# [30 rows x 23 columns]

# %%
temp1[['Excess','Lag']].iloc[:100,:].plot(marker='.')

# %%
df_r_test.columns
# Out:
# Index(['PERIOD (FORMATTED)', 'IDENTIFIER', 'RET24M_L1M', 'ARM_PFD_COMP',
#        '1SS_ERNQLT', 'PP_RANK', 'RISK', 'Excess', 'RET24M_L1M_Rol',
#        'ARM_PFD_COMP_Rol', '1SS_ERNQLT_Rol', 'PP_RANK_Rol', 'RISK_Rol',
#        'RET24M_L1MLagDiff', 'ARM_PFD_COMPLagDiff', '1SS_ERNQLTLagDiff',
#        'PP_RANKLagDiff', 'RISKLagDiff', 'RET24M_L1M_SUM', 'ARM_PFD_COMP_SUM',
#        '1SS_ERNQLT_SUM', 'PP_RANK_SUM', 'RISK_SUM', 'Lag'],
#       dtype='object')

# %%
# Capital one USA
id='14040H10'
temp1 = df_r_test[df_r_test.IDENTIFIER==id]
temp1
# Out:
#                    IDENTIFIER  RET24M_L1M  ARM_PFD_COMP  1SS_ERNQLT   PP_RANK  \
# PERIOD (FORMATTED)
# 2015-06-05           14040H10    0.000646      0.135403    0.018936  0.038051
# 2015-08-28           14040H10   -0.000628     -0.117122   -0.082074  0.128960
# 2015-07-24           14040H10    0.001030     -0.268637   -0.001266  0.068354
# 2015-10-16           14040H10   -0.000625     -0.127223   -0.102277  0.128960
# 2015-09-25           14040H10   -0.000902     -0.066617   -0.092176  0.128960
# 2015-07-31           14040H10    0.000615     -0.238334   -0.001266  0.088556
# 2015-08-21           14040H10    0.000243     -0.167627   -0.082074  0.128960
# 2015-09-04           14040H10   -0.000528     -0.117122   -0.092176  0.128960
# 2015-08-14           14040H10    0.000278     -0.167627   -0.071973  0.128960
# 2015-07-10           14040H10    0.000565      0.175807   -0.001266  0.038051
# 2015-09-11           14040H10   -0.000422     -0.127223   -0.092176  0.118859
# 2015-08-07           14040H10    0.000310     -0.187829   -0.071973  0.128960
# 2015-07-17           14040H10    0.000695      0.216211   -0.001266  0.038051
# 2015-06-19           14040H10    0.000638      0.206110    0.018936  0.038051
# 2015-11-20           14040H10   -0.001116      0.014191   -0.082074  0.108758
# 2015-06-26           14040H10    0.000490      0.165706    0.008835  0.038051
# 2015-09-18           14040H10   -0.000301     -0.127223   -0.092176  0.118859
# 2015-07-03           14040H10    0.000512      0.155605   -0.001266  0.038051
# 2015-10-30           14040H10   -0.001045      0.024292   -0.102277  0.118859
# 2015-12-25           14040H10   -0.000684     -0.066617   -0.082074  0.108758
