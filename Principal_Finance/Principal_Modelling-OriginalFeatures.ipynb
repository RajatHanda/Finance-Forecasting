# %% [markdown]
#  Author: RAJAT HANDA

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model as lm
from sklearn import metrics
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import Ridge
import scipy.stats as stat
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Train Dataset

# %%
df_train=pd.read_csv('Pr_train_20.csv',parse_dates=['PERIOD (FORMATTED)'],index_col='PERIOD (FORMATTED)',
                 infer_datetime_format=True, encoding='utf-8')

# %%
df_train.head()
# Out:
#                    IDENTIFIER      RANK    1M_RET      MCAP  1SS_ERNQLT  \
# PERIOD (FORMATTED)
# 2015-08-07             B66Y3W  0.000710 -0.001156 -0.000904    0.001082
# 2015-08-14           46625H10 -0.457558 -0.000262  0.039349    0.018936
# 2015-08-14           22531010 -0.437356 -0.001977 -0.001736    0.130047
# 2015-08-14           68193610  0.037392  0.000447 -0.001328   -0.354802
# 2015-08-14           05348410 -0.417154  0.000501  0.001474    0.018936
#
#                     IST_SURPY1      ACCX  ARM_PFD_COMP  RET24M_L1M  RSI_12M.1  \
# PERIOD (FORMATTED)
# 2015-08-07            0.000016 -0.004091     -0.288839   -0.002757  -0.115162
# 2015-08-14            0.000187  0.019779     -0.036314    0.000010   0.031485
# 2015-08-14            0.000200  0.013598      0.236413    0.004571   0.058348
# 2015-08-14            0.000248  0.019990      0.256615   -0.000507  -0.014272
# 2015-08-14            0.000332  0.005642      0.377827   -0.000229   0.030606
#
#                       ...      CASH_P.1      EV.1  RVM_CFO_AST.1  VALUE_COM.1  \
# PERIOD (FORMATTED)    ...
# 2015-08-07            ...     -0.002576  0.000341       0.012645    -0.009822
# 2015-08-14            ...      0.032568  0.016625       0.003394     0.021311
# 2015-08-14            ...     -0.001472 -0.001722      -0.007786    -0.100819
# 2015-08-14            ...     -0.001069 -0.001453       0.003451     0.002316
# 2015-08-14            ...     -0.002477  0.000800      -0.047704    -0.052720
#
#                     QUALITY.1      RISK  TECHNICAL1.1   PP_RANK  \
# PERIOD (FORMATTED)
# 2015-08-07          -0.019840  0.014736     -0.147384 -0.244777
# 2015-08-14          -0.001720  0.005954      0.041049  0.068354
# 2015-08-14           0.001062  0.059482     -0.050510 -0.436697
# 2015-08-14          -0.004681  0.011318     -0.024707 -0.315484
# 2015-08-14          -0.002440  0.020004      0.103849 -0.396293
#
#                     FUTURE 24 WEEK RETURNS     Excess
# PERIOD (FORMATTED)
# 2015-08-07                      -21.837562 -25.108537
# 2015-08-14                      -11.073070 -14.344045
# 2015-08-14                      -13.421253 -16.692228
# 2015-08-14                       -9.963345 -13.234320
# 2015-08-14                       -1.768926  -5.039901
#
# [5 rows x 21 columns]

# %%
cols_to_not_use = {'Excess','FUTURE 24 WEEK RETURNS', 'IDENTIFIER', 'PERIOD (FORMATTED)'}
cols_to_use = list(filter(lambda c: c not in cols_to_not_use, df_train.columns))

# %% [markdown]
# ## Linear Model

# %%
lm_model=lm.LinearRegression()

# %%
df_train[cols_to_use]
# Out:
#                         RANK    1M_RET      MCAP  1SS_ERNQLT    IST_SURPY1  \
# PERIOD (FORMATTED)
# 2015-08-07          0.000710 -0.001156 -0.000904    0.001082  1.567468e-05
# 2013-04-05          0.001808     -0.040485  0.240071
# 2013-04-05          0.003454      0.098206  0.310778
# 2013-04-05          0.018873     -0.133655  0.219869
# 2013-04-12          0.040921     -0.081325  0.442091
# 2013-04-12         -0.053141      0.043678 -0.234676
# 2013-04-12         -0.015570      0.050602  0.219869
# 2013-04-12          0.060219      0.044977  0.280475
# 2013-04-19         -0.164063      0.070141 -0.264979
# 2013-04-19          0.113382     -0.035912  0.411788
# 2013-04-19          0.011885      0.107638  0.001638
# 2013-04-19         -0.063296      0.131819  0.260273
# 2013-04-19         -0.038935      0.153260  0.199667
# 2013-04-19          0.002162     -0.095743 -0.022555
# 2013-04-26         -0.132998      0.071289 -0.083161
# 2013-04-26         -0.023458     -0.114647 -0.456899
# 2013-04-26         -0.111496      0.081748 -0.477101
# 2013-04-26         -0.038943      0.106063  0.199667
# 2013-04-26          0.011322     -0.144293  0.381485
# 2013-04-26         -0.105914      0.158136 -0.295282
# 2013-04-26          0.026426      0.016233  0.361283
# 2013-04-26         -0.023285     -0.112249 -0.052858
# 2013-05-03          0.099948      0.056315  0.128960
# 2013-05-03          0.014674      0.024308  0.371384
# 2013-05-03          0.040358     -0.141307  0.381485
# 2013-05-03          0.004207     -0.061434  0.320879
# 2013-05-03          0.189415     -0.090507  0.411788
# 2013-05-10          0.093753     -0.085622  0.371384
# 2013-05-10          0.051321     -0.102634  0.270374
#
# [1082705 rows x 18 columns]

# %%
lm_model.fit(df_train[cols_to_use], df_train['Excess'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm_model.intercept_
# Out:
# 0.025563112230195442

# %%
lm_model.coef_
# Out:
# array([ -5.46112019e-01,  -1.22610048e+03,  -5.71578099e+00,
#          2.09968064e+00,   6.09774707e+01,  -3.08410836e+00,
#          4.44708780e+00,  -4.78581044e+02,   2.21603743e+01,
#          1.01122168e+01,   3.09835435e+01,  -4.26309016e+01,
#          5.48573696e+00,   1.78640203e+01,   4.39530419e+00,
#         -4.81450718e+00,   6.99491229e+00,  -2.17300092e+00])

# %% [markdown]
# ## Extra Tree Regressor

# %%
ETR_model = ExtraTreesRegressor(n_estimators=100, max_depth=4, n_jobs=-1, random_state=17, verbose=0)
model2 = ETR_model.fit(df_train[cols_to_use], df_train['Excess'])

# %% [markdown]
# ## Ridge

# %%
Rid=Ridge()
model3=Rid.fit(df_train[cols_to_use], df_train['Excess'])

# %% [markdown]
# ## test data

# %%
df_test=pd.read_csv('Pr_test_20.csv',parse_dates=['PERIOD (FORMATTED)'],index_col='PERIOD (FORMATTED)',
                 infer_datetime_format=True, encoding='utf-8')

# %% [markdown]
# ## Model Predicitons

# %% [markdown]
# ### Linear Model

# %%
Preds_Excess=lm_model.predict(df_test[cols_to_use])

# %% [markdown]
# ### Extra Tree

# %%
Preds_Excess_2=model2.predict(df_test[cols_to_use])

# %% [markdown]
# ### Ridge

# %%
Preds_Excess_4=model3.predict(df_test[cols_to_use])

# %% [markdown]
# ### COMBINING EXTRA TREE AND RIDGE

# %%
Preds_Excess_3=(model2.predict(df_test[cols_to_use])*0.95)+(model3.predict(df_test[cols_to_use])*0.05)

# %% [markdown]
# ## Validating our model

# %% [markdown]
# ### Linear Model

# %%
#MAE
metrics.mean_absolute_error(df_test['Excess'],Preds_Excess)
# Out:
# 13.837777519024524

# %%
#MSE
metrics.mean_squared_error(df_test['Excess'],Preds_Excess)
# Out:
# 373.86423050532272

# %%
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess))
# Out:
# 19.335569050465587

# %%
#MAPE
np.mean(np.abs((df_test['Excess'] - Preds_Excess) / df_test['Excess'])) * 100
# Out:
# 284.58477535061178

# %%
# Spearman Coorelation
stat.spearmanr(df_test['Excess'],Preds_Excess)[0]
# Out:
# 0.037162181993491576

# %% [markdown]
# ### Extra Tree

# %%
#MAE
metrics.mean_absolute_error(df_test['Excess'],Preds_Excess_2)
# Out:
# 13.742206810730359

# %%
#MSE
metrics.mean_squared_error(df_test['Excess'],Preds_Excess_2)
# Out:
# 358.21138932465084

# %%
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_2))
# Out:
# 18.926473240534033

# %%
#MAPE
np.mean(np.abs((df_test['Excess'] - Preds_Excess_2) / df_test['Excess'])) * 100
# Out:
# 199.11265152620362

# %%
# Spearman Coorelation
stat.spearmanr(df_test['Excess'],Preds_Excess_2)[0]
# Out:
# 0.048775937022596999

# %% [markdown]
# ### Ridge

# %%
#MAE
metrics.mean_absolute_error(df_test['Excess'],Preds_Excess_4)
# Out:
# 13.817997567014469

# %%
#MSE
metrics.mean_squared_error(df_test['Excess'],Preds_Excess_4)
# Out:
# 361.5441972860533

# %%
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_4))
# Out:
# 19.014315588157604

# %%
#MAPE
np.mean(np.abs((df_test['Excess'] - Preds_Excess_4) / df_test['Excess'])) * 100
# Out:
# 283.51281964876716

# %%
# Spearman Coorelation
stat.spearmanr(df_test['Excess'],Preds_Excess_4)[0]
# Out:
# 0.038977849142670024

# %% [markdown]
# ### Combining EXTRA TREE AND RIDGE

# %%
#MAE
metrics.mean_absolute_error(df_test['Excess'],Preds_Excess_3)
# Out:
# 13.742653583970375

# %%
#MSE
metrics.mean_squared_error(df_test['Excess'],Preds_Excess_3)
# Out:
# 358.08081137131251

# %%
#RMSE
np.sqrt(metrics.mean_squared_error(df_test['Excess'],Preds_Excess_3))
# Out:
# 18.923023314769566

# %%
#MAPE
np.mean(np.abs((df_test['Excess'] - Preds_Excess_3) / df_test['Excess'])) * 100
# Out:
# 201.64155498760036

# %%
# Spearman Coorelation
stat.spearmanr(df_test['Excess'],Preds_Excess_3)[0]
# Out:
# 0.048840642670072806

# %%
imp = pd.DataFrame(index=cols_to_use)
imp['train'] = pd.Series(model2.feature_importances_, index=cols_to_use)

# %%
ax = imp.sort_values('train').tail(10).plot.barh(title='Feature importances With Normal Metrics(ETR)', figsize=(10,6))

# %%
imp_R = pd.DataFrame(index=cols_to_use)
imp_R['train'] = pd.Series(model3.coef_, index=cols_to_use)

# %%
ax = imp_R.sort_values('train').tail(10).plot.barh(title='Feature importances with derived Varibales(Ridge)', figsize=(10,6))
